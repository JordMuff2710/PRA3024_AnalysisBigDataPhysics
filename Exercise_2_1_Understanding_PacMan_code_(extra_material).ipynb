# %% [markdown]
# <a href="https://colab.research.google.com/github/JordMuff2710/PRA3024_AnalysisBigDataPhysics/blob/master/Exercise_2_1_Understanding_PacMan_code_(extra_material).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building an Agent to Play Miss PacMan games using Deep Q Network, in Tensorflow 2.0.
#
# ### A Colaboratory notebook for GradientCrescent, by Adrian Yijie Xu.
#
# ### If you enjoyed this notebook, please consider leaving a star on the GradientCrescent Github (https://github.com/EXJUSTICE/GradientCrescent), and visting the publication for more articles on applied and theoretical aspects of AI (https://medium.com/gradientcrescent).

# %% [markdown]
# ## Training
#
# First we import all the necessary libraries </font>

# %%
import numpy as np
import gym
import tensorflow as tf
from tensorflow.contrib.layers import flatten, conv2d, fully_connected
from collections import deque, Counter
import random
from datetime import datetime
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
print(tf.__version__)
# Out:
# 1.15.0

# %% [markdown]
# Now we define a preprocessing function for our input game screens. We crop the image size convert the image into greyscale 1D tensor

# %%
color = np.array([210, 164, 74]).mean()


#prepro (210, 160, 3) uint8 frame into 7040 (88x80) 1D float vector 

def preprocess_observation(obs):

    # Crop and resize the image
    img = obs[1:176:2, ::2]

    # Convert the image to greyscale
    img = img.mean(axis=2)

    # Improve image contrast
    img[img==color] = 0

    # Next we normalize the image from -1 to +1
    img = (img - 128) / 128 - 1

    return img.reshape(88,80,1)

# %% [markdown]
# Let us initialize our gym environment, and take a look at some observations. Let's also inspect the size and type of action space in this game.

# %%
env = gym.make("MsPacman-v0")
n_outputs = env.action_space.n
print(n_outputs)
print(env.env.get_action_meanings())

observation = env.reset()

import tensorflow as tf
import matplotlib.pyplot as plt


for i in range(22):
  
  if i > 20:
    plt.imshow(observation)
    plt.show()

  observation, _, _, _ = env.step(1)
# Out:
# 9
# ['NOOP', 'UP', 'RIGHT', 'LEFT', 'DOWN', 'UPRIGHT', 'UPLEFT', 'DOWNRIGHT', 'DOWNLEFT']

# %%
#Take a look at the preprocessed inputs in greyscale
#Let's compare the original and preprocessed tensors.

obs_preprocessed = preprocess_observation(observation).reshape(88,80)
plt.imshow(obs_preprocessed)
plt.show()
print(observation.shape)
print(obs_preprocessed.shape)
# Out:
# (210, 160, 3)
# (88, 80)

# %% [markdown]
# Okay, Now we define a function called q_network for building our Deep Q network.  <br>
# We build Q network with three convolutional layers with same padding followed by a flattening, and a fully connected layer.

# %%
tf.compat.v1.reset_default_graph()
#Reset is technically not necessary if variables done  in TF2
#https://github.com/ageron/tf2_course/issues/8

def q_network(X, name_scope):
    
    # Initialize layers
    initializer = tf.compat.v1.keras.initializers.VarianceScaling(scale=2.0)

    with tf.compat.v1.variable_scope(name_scope) as scope: 


        # initialize the convolutional layers
        layer_1 = conv2d(X, num_outputs=32, kernel_size=(8,8), stride=4, padding='SAME', weights_initializer=initializer) 
        tf.compat.v1.summary.histogram('layer_1',layer_1)
        
        layer_2 = conv2d(layer_1, num_outputs=64, kernel_size=(4,4), stride=2, padding='SAME', weights_initializer=initializer)
        tf.compat.v1.summary.histogram('layer_2',layer_2)
        
        layer_3 = conv2d(layer_2, num_outputs=64, kernel_size=(3,3), stride=1, padding='SAME', weights_initializer=initializer)
        tf.compat.v1.summary.histogram('layer_3',layer_3)
        
        # Flatten the result of layer_3 before feeding to the fully connected layer
        flat = flatten(layer_3)
        # Insert fully connected layer
        fc = fully_connected(flat, num_outputs=128, weights_initializer=initializer)
        tf.compat.v1.summary.histogram('fc',fc)
        #Add final output layer
        output = fully_connected(fc, num_outputs=n_outputs, activation_fn=None, weights_initializer=initializer)
        tf.compat.v1.summary.histogram('output',output)
        

        # Vars will store the parameters of the network such as weights
        vars = {v.name[len(scope.name):]: v for v in tf.compat.v1.get_collection(key=tf.compat.v1.GraphKeys.TRAINABLE_VARIABLES, scope=scope.name)} 
        #Return both variables and outputs together
        return vars, output

# %% [markdown]
# Next we define a function called epsilon_greedy for performing epsilon greedy policy.
#
# In epsilon greedy policy we either select the best action with probability [1 - epsilon] or a random action with
# probability [epsilon].
#
#
# We use decaying epsilon greedy policy where value of epsilon will be decaying over time as we don't want to explore
# forever. So over time our policy will be exploiting only good actions.

# %%
epsilon = 0.5
eps_min = 0.05
eps_max = 1.0
eps_decay_steps = 500000

#
def epsilon_greedy(action, step):
    p = np.random.random(1).squeeze() #1D entries returned using squeeze
    epsilon = max(eps_min, eps_max - (eps_max-eps_min) * step/eps_decay_steps) #Decaying policy with more steps
    if np.random.rand() < epsilon:
        return np.random.randint(n_outputs)
    else:
        return action

# %% [markdown]
# Now, we initialize our  buffer of length 20000 which holds the gameplay information in SARSA.
#
# We store all the agent's experience i.e (state, action, rewards) in the experience replay buffer
# and  we sample from this minibatch of experience for generating the y-values for the update function, and hence train the network.

# %%
buffer_len = 20000
#Buffer is made from a deque - double ended queue
exp_buffer = deque(maxlen=buffer_len)

# %% [markdown]
# Next, we define a function called sample_memories for sampling experiences from the memory according to batches. Batch size is the number of experience sampled
# from the memory.

# %%
def sample_memories(batch_size):
    perm_batch = np.random.permutation(len(exp_buffer))[:batch_size]
    mem = np.array(exp_buffer)[perm_batch]
    return mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]

# %% [markdown]
# Now we define our network hyperparameters,

# %%
num_episodes = 800
batch_size = 48
input_shape = (None, 88, 80, 1)
#Recall shape is img.reshape(88,80,1)
learning_rate = 0.001
X_shape = (None, 88, 80, 1)
discount_factor = 0.97

global_step = 0
copy_steps = 100
steps_train = 4
start_steps = 2000

# %%
logdir = 'logs'
tf.compat.v1.reset_default_graph()

# Now we define the placeholder for our input i.e game state
X = tf.compat.v1.placeholder(tf.float32, shape=X_shape)

# we define a boolean called in_training_model to toggle the training
in_training_mode = tf.compat.v1.placeholder(tf.bool)

# %% [markdown]
#  Now let us build our primary and target Q network We have two networks to allow for training and data generation to occur concurrently.
#  Note that the network returns the weights, as well as network outputs.

# %%
# we build our Q network, which takes the input X and generates Q values for all the actions in the state
mainQ, mainQ_outputs = q_network(X, 'mainQ')

# similarly we build our target Q network
targetQ, targetQ_outputs = q_network(X, 'targetQ')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.

# %%
# define the placeholder for our action values

X_action = tf.compat.v1.placeholder(tf.int32, shape=(None,))
Q_action = tf.reduce_sum(input_tensor=targetQ_outputs * tf.one_hot(X_action, n_outputs), axis=-1, keepdims=True)

# %% [markdown]
# Copy the primary Q network parameters to the target  Q network

# %%
copy_op = [tf.compat.v1.assign(main_name, targetQ[var_name]) for var_name, main_name in mainQ.items()]
copy_target_to_main = tf.group(*copy_op)

# %% [markdown]
# Compute and optimize loss using gradient descent optimizer

# %%
# define a placeholder for our output i.e action
y = tf.compat.v1.placeholder(tf.float32, shape=(None,1))

# now we calculate the loss which is the difference between actual value and predicted value
loss = tf.reduce_mean(input_tensor=tf.square(y - Q_action))

# we use adam optimizer for minimizing the loss
optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate)
training_op = optimizer.minimize(loss)

init = tf.compat.v1.global_variables_initializer()

loss_summary = tf.compat.v1.summary.scalar('LOSS', loss)
merge_summary = tf.compat.v1.summary.merge_all()
file_writer = tf.compat.v1.summary.FileWriter(logdir, tf.compat.v1.get_default_graph())

# %% [markdown]
#  Now we start the tensorflow session and run the model,
#
# 1. First, we preprocess and feed the game screen (state s) to our DQN, which will
# return the Q values of all possible actions in the state.
# 2. Now we select an action using the epsilon-greedy policy: with the probability
# epsilon, we select a random action a and with probability 1-epsilon, we select an
# action that has a maximum Q value, such as .
# 3. After selecting the action a, we perform this action in a state s and move to a new
# state s' and receive a reward. The next state, s', is the preprocessed image of the
# next game screen.
# 4. We store this transition in our replay buffer as <s,a,r,s'>.
# 5. Next, we sample some random batches of transitions from the replay buffer and
# calculate the loss.
#
# 6. We know that the loss is defined as the squared
# difference between target Q and predicted Q.
#
# 7. We perform gradient descent with respect to our actual network parameters in
# order to minimize this loss.
#
# 8. Copy weights of training network to actual network
# 9. Repeat for M steps
#
# Epochs here exist because we are suplying data in batches.

# %%
with tf.compat.v1.Session() as sess:
    init.run()
    
    # for each episode
    history = []
    for i in range(num_episodes):
        done = False
        obs = env.reset()
        epoch = 0
        episodic_reward = 0
        actions_counter = Counter() 
        episodic_loss = []

        # while the state is not the terminal state
        while not done:

           #env.render()
        
            # get the preprocessed game screen
            obs = preprocess_observation(obs)

            # feed the game screen and get the Q values for each action,  FEED THE NETWORK BY CALLING THE OUTPUT LAYER
            
            actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

            # get the action
            action = np.argmax(actions, axis=-1)
            actions_counter[str(action)] += 1 

            # select the action using epsilon greedy policy
            action = epsilon_greedy(action, global_step)
            
            # now perform the action and move to the next state, next_obs, receive reward
            next_obs, reward, done, _ = env.step(action)

            # Store this transistion as an experience in the replay buffer! Quite important
            exp_buffer.append([obs, action, preprocess_observation(next_obs), reward, done])
            
            # After certain steps, we train our Q network with samples from the experience replay buffer
            if global_step % steps_train == 0 and global_step > start_steps:
                
                # sample experience, mem[:,0], mem[:,1], mem[:,2], mem[:,3], mem[:,4]
                o_obs, o_act, o_next_obs, o_rew, o_done = sample_memories(batch_size)

                # states
                o_obs = [x for x in o_obs]

                # next states
                o_next_obs = [x for x in o_next_obs]

                # next actions
                next_act = mainQ_outputs.eval(feed_dict={X:o_next_obs, in_training_mode:False})


                # discounted reward: these are our Y-values
                y_batch = o_rew + discount_factor * np.max(next_act, axis=-1) * (1-o_done) 

                # merge all summaries and write to the file
                mrg_summary = merge_summary.eval(feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:False})
                file_writer.add_summary(mrg_summary, global_step)

                # To calculate the loss, we run the previously defined functions mentioned while feeding inputs
                train_loss, _ = sess.run([loss, training_op], feed_dict={X:o_obs, y:np.expand_dims(y_batch, axis=-1), X_action:o_act, in_training_mode:True})
                episodic_loss.append(train_loss)
            
            # after some interval we copy our main Q network weights to target Q network
            if (global_step+1) % copy_steps == 0 and global_step > start_steps:
                copy_target_to_main.run()
                
            obs = next_obs
            epoch += 1
            global_step += 1
            episodic_reward += reward
        
        history.append(episodic_reward)
        print('Epochs per episode:', epoch, 'Episode Reward:', episodic_reward,"Episode number:", len(history))
# Out:
# Epochs per episode: 619 Episode Reward: 180.0 Episode number: 1
# Epochs per episode: 796 Episode Reward: 390.0 Episode number: 2
# Epochs per episode: 624 Episode Reward: 190.0 Episode number: 3
# Epochs per episode: 624 Episode Reward: 220.0 Episode number: 4
# Epochs per episode: 558 Episode Reward: 130.0 Episode number: 5
# Epochs per episode: 648 Episode Reward: 200.0 Episode number: 6
# Epochs per episode: 681 Episode Reward: 310.0 Episode number: 7
# Epochs per episode: 658 Episode Reward: 200.0 Episode number: 8
# Epochs per episode: 661 Episode Reward: 160.0 Episode number: 9
# Epochs per episode: 697 Episode Reward: 180.0 Episode number: 10
# Epochs per episode: 738 Episode Reward: 230.0 Episode number: 11
# Epochs per episode: 728 Episode Reward: 160.0 Episode number: 12
# Epochs per episode: 675 Episode Reward: 250.0 Episode number: 13
# Epochs per episode: 720 Episode Reward: 260.0 Episode number: 14
# Epochs per episode: 637 Episode Reward: 190.0 Episode number: 15
# Epochs per episode: 644 Episode Reward: 230.0 Episode number: 16
# Epochs per episode: 687 Episode Reward: 210.0 Episode number: 17
# Epochs per episode: 680 Episode Reward: 190.0 Episode number: 18
# Epochs per episode: 738 Episode Reward: 190.0 Episode number: 19
# Epochs per episode: 629 Episode Reward: 220.0 Episode number: 20
# Epochs per episode: 557 Episode Reward: 130.0 Episode number: 21
# Epochs per episode: 1018 Episode Reward: 480.0 Episode number: 22
# Epochs per episode: 662 Episode Reward: 180.0 Episode number: 23
# Epochs per episode: 618 Episode Reward: 210.0 Episode number: 24
# Epochs per episode: 645 Episode Reward: 220.0 Episode number: 25
# Epochs per episode: 558 Episode Reward: 160.0 Episode number: 26
# Epochs per episode: 663 Episode Reward: 200.0 Episode number: 27
# Epochs per episode: 756 Episode Reward: 260.0 Episode number: 28
# Epochs per episode: 545 Episode Reward: 190.0 Episode number: 29
# Epochs per episode: 740 Episode Reward: 220.0 Episode number: 30
# Epochs per episode: 459 Episode Reward: 90.0 Episode number: 31
# Epochs per episode: 570 Episode Reward: 220.0 Episode number: 32
# Epochs per episode: 635 Episode Reward: 250.0 Episode number: 33
# Epochs per episode: 968 Episode Reward: 560.0 Episode number: 34
# Epochs per episode: 609 Episode Reward: 200.0 Episode number: 35
# Epochs per episode: 626 Episode Reward: 220.0 Episode number: 36
# Epochs per episode: 504 Episode Reward: 190.0 Episode number: 37
# Epochs per episode: 661 Episode Reward: 210.0 Episode number: 38
# Epochs per episode: 699 Episode Reward: 210.0 Episode number: 39
# Epochs per episode: 687 Episode Reward: 220.0 Episode number: 40
# Epochs per episode: 695 Episode Reward: 300.0 Episode number: 41
# Epochs per episode: 642 Episode Reward: 240.0 Episode number: 42
# Epochs per episode: 872 Episode Reward: 340.0 Episode number: 43
# Epochs per episode: 545 Episode Reward: 140.0 Episode number: 44
# Epochs per episode: 581 Episode Reward: 140.0 Episode number: 45
# Epochs per episode: 717 Episode Reward: 140.0 Episode number: 46
# Epochs per episode: 625 Episode Reward: 270.0 Episode number: 47
# Epochs per episode: 713 Episode Reward: 260.0 Episode number: 48
# Epochs per episode: 707 Episode Reward: 270.0 Episode number: 49
# Epochs per episode: 627 Episode Reward: 160.0 Episode number: 50
# Epochs per episode: 1115 Episode Reward: 390.0 Episode number: 51
# Epochs per episode: 530 Episode Reward: 130.0 Episode number: 52
# Epochs per episode: 626 Episode Reward: 250.0 Episode number: 53
# Epochs per episode: 598 Episode Reward: 220.0 Episode number: 54
# Epochs per episode: 760 Episode Reward: 290.0 Episode number: 55
# Epochs per episode: 556 Episode Reward: 200.0 Episode number: 56
# Epochs per episode: 616 Episode Reward: 200.0 Episode number: 57
# Epochs per episode: 649 Episode Reward: 140.0 Episode number: 58
# Epochs per episode: 858 Episode Reward: 240.0 Episode number: 59
# Epochs per episode: 832 Episode Reward: 290.0 Episode number: 60
# Epochs per episode: 703 Episode Reward: 240.0 Episode number: 61
# Epochs per episode: 627 Episode Reward: 270.0 Episode number: 62
# Epochs per episode: 729 Episode Reward: 180.0 Episode number: 63
# Epochs per episode: 633 Episode Reward: 200.0 Episode number: 64
# Epochs per episode: 645 Episode Reward: 330.0 Episode number: 65
# Epochs per episode: 832 Episode Reward: 360.0 Episode number: 66
# Epochs per episode: 612 Episode Reward: 210.0 Episode number: 67
# Epochs per episode: 688 Episode Reward: 190.0 Episode number: 68
# Epochs per episode: 723 Episode Reward: 320.0 Episode number: 69
# Epochs per episode: 583 Episode Reward: 180.0 Episode number: 70
# Epochs per episode: 696 Episode Reward: 270.0 Episode number: 71
# Epochs per episode: 668 Episode Reward: 270.0 Episode number: 72
# Epochs per episode: 688 Episode Reward: 270.0 Episode number: 73
# Epochs per episode: 702 Episode Reward: 190.0 Episode number: 74
# Epochs per episode: 646 Episode Reward: 200.0 Episode number: 75
# Epochs per episode: 573 Episode Reward: 180.0 Episode number: 76
# Epochs per episode: 702 Episode Reward: 300.0 Episode number: 77
# Epochs per episode: 530 Episode Reward: 160.0 Episode number: 78
# Epochs per episode: 719 Episode Reward: 210.0 Episode number: 79
# Epochs per episode: 701 Episode Reward: 220.0 Episode number: 80
# Epochs per episode: 698 Episode Reward: 260.0 Episode number: 81
# Epochs per episode: 661 Episode Reward: 250.0 Episode number: 82
# Epochs per episode: 790 Episode Reward: 240.0 Episode number: 83
# Epochs per episode: 566 Episode Reward: 140.0 Episode number: 84
# Epochs per episode: 738 Episode Reward: 190.0 Episode number: 85
# Epochs per episode: 684 Episode Reward: 250.0 Episode number: 86
# Epochs per episode: 751 Episode Reward: 260.0 Episode number: 87
# Epochs per episode: 692 Episode Reward: 220.0 Episode number: 88
# Epochs per episode: 673 Episode Reward: 290.0 Episode number: 89
# Epochs per episode: 646 Episode Reward: 220.0 Episode number: 90
# Epochs per episode: 694 Episode Reward: 240.0 Episode number: 91
# Epochs per episode: 598 Episode Reward: 140.0 Episode number: 92
# Epochs per episode: 747 Episode Reward: 360.0 Episode number: 93
# Epochs per episode: 739 Episode Reward: 270.0 Episode number: 94
# Epochs per episode: 621 Episode Reward: 140.0 Episode number: 95
# Epochs per episode: 684 Episode Reward: 220.0 Episode number: 96
# Epochs per episode: 625 Episode Reward: 210.0 Episode number: 97
# Epochs per episode: 587 Episode Reward: 220.0 Episode number: 98
# Epochs per episode: 572 Episode Reward: 220.0 Episode number: 99
# Epochs per episode: 633 Episode Reward: 260.0 Episode number: 100
# Epochs per episode: 499 Episode Reward: 180.0 Episode number: 101
# Epochs per episode: 679 Episode Reward: 250.0 Episode number: 102
# Epochs per episode: 1334 Episode Reward: 520.0 Episode number: 103
# Epochs per episode: 616 Episode Reward: 240.0 Episode number: 104
# Epochs per episode: 482 Episode Reward: 60.0 Episode number: 105
# Epochs per episode: 652 Episode Reward: 180.0 Episode number: 106
# Epochs per episode: 652 Episode Reward: 270.0 Episode number: 107
# Epochs per episode: 685 Episode Reward: 250.0 Episode number: 108
# Epochs per episode: 594 Episode Reward: 170.0 Episode number: 109
# Epochs per episode: 837 Episode Reward: 350.0 Episode number: 110
# Epochs per episode: 661 Episode Reward: 280.0 Episode number: 111
# Epochs per episode: 658 Episode Reward: 190.0 Episode number: 112
# Epochs per episode: 547 Episode Reward: 180.0 Episode number: 113
# Epochs per episode: 620 Episode Reward: 230.0 Episode number: 114
# Epochs per episode: 645 Episode Reward: 270.0 Episode number: 115
# Epochs per episode: 666 Episode Reward: 310.0 Episode number: 116
# Epochs per episode: 539 Episode Reward: 110.0 Episode number: 117
# Epochs per episode: 528 Episode Reward: 180.0 Episode number: 118
# Epochs per episode: 542 Episode Reward: 170.0 Episode number: 119
# Epochs per episode: 643 Episode Reward: 270.0 Episode number: 120
# Epochs per episode: 654 Episode Reward: 240.0 Episode number: 121
# Epochs per episode: 603 Episode Reward: 260.0 Episode number: 122
# Epochs per episode: 554 Episode Reward: 160.0 Episode number: 123
# Epochs per episode: 574 Episode Reward: 190.0 Episode number: 124
# Epochs per episode: 780 Episode Reward: 310.0 Episode number: 125
# Epochs per episode: 657 Episode Reward: 270.0 Episode number: 126
# Epochs per episode: 554 Episode Reward: 250.0 Episode number: 127
# Epochs per episode: 697 Episode Reward: 230.0 Episode number: 128
# Epochs per episode: 729 Episode Reward: 250.0 Episode number: 129
# Epochs per episode: 518 Episode Reward: 230.0 Episode number: 130
# Epochs per episode: 569 Episode Reward: 180.0 Episode number: 131
# Epochs per episode: 593 Episode Reward: 190.0 Episode number: 132
# Epochs per episode: 623 Episode Reward: 230.0 Episode number: 133
# Epochs per episode: 637 Episode Reward: 260.0 Episode number: 134
# Epochs per episode: 530 Episode Reward: 310.0 Episode number: 135
# Epochs per episode: 713 Episode Reward: 310.0 Episode number: 136
# Epochs per episode: 918 Episode Reward: 380.0 Episode number: 137
# Epochs per episode: 560 Episode Reward: 180.0 Episode number: 138
# Epochs per episode: 664 Episode Reward: 260.0 Episode number: 139
# Epochs per episode: 688 Episode Reward: 230.0 Episode number: 140
# Epochs per episode: 811 Episode Reward: 420.0 Episode number: 141
# Epochs per episode: 569 Episode Reward: 230.0 Episode number: 142
# Epochs per episode: 605 Episode Reward: 280.0 Episode number: 143
# Epochs per episode: 536 Episode Reward: 240.0 Episode number: 144
# Epochs per episode: 648 Episode Reward: 230.0 Episode number: 145
# Epochs per episode: 642 Episode Reward: 240.0 Episode number: 146
# Epochs per episode: 1308 Episode Reward: 1260.0 Episode number: 147
# Epochs per episode: 655 Episode Reward: 240.0 Episode number: 148
# Epochs per episode: 578 Episode Reward: 240.0 Episode number: 149
# Epochs per episode: 672 Episode Reward: 270.0 Episode number: 150
# Epochs per episode: 660 Episode Reward: 180.0 Episode number: 151
# Epochs per episode: 618 Episode Reward: 330.0 Episode number: 152
# Epochs per episode: 716 Episode Reward: 420.0 Episode number: 153
# Epochs per episode: 665 Episode Reward: 250.0 Episode number: 154
# Epochs per episode: 738 Episode Reward: 300.0 Episode number: 155
# Epochs per episode: 680 Episode Reward: 260.0 Episode number: 156
# Epochs per episode: 1076 Episode Reward: 560.0 Episode number: 157
# Epochs per episode: 566 Episode Reward: 270.0 Episode number: 158
# Epochs per episode: 738 Episode Reward: 330.0 Episode number: 159
# Epochs per episode: 610 Episode Reward: 230.0 Episode number: 160
# Epochs per episode: 522 Episode Reward: 180.0 Episode number: 161
# Epochs per episode: 601 Episode Reward: 220.0 Episode number: 162
# Epochs per episode: 605 Episode Reward: 280.0 Episode number: 163
# Epochs per episode: 666 Episode Reward: 230.0 Episode number: 164
# Epochs per episode: 484 Episode Reward: 130.0 Episode number: 165
# Epochs per episode: 797 Episode Reward: 310.0 Episode number: 166
# Epochs per episode: 586 Episode Reward: 250.0 Episode number: 167
# Epochs per episode: 589 Episode Reward: 280.0 Episode number: 168
# Epochs per episode: 996 Episode Reward: 230.0 Episode number: 169
# Epochs per episode: 666 Episode Reward: 310.0 Episode number: 170
# Epochs per episode: 831 Episode Reward: 430.0 Episode number: 171
# Epochs per episode: 1040 Episode Reward: 700.0 Episode number: 172
# Epochs per episode: 1059 Episode Reward: 970.0 Episode number: 173
# Epochs per episode: 704 Episode Reward: 390.0 Episode number: 174
# Epochs per episode: 541 Episode Reward: 180.0 Episode number: 175
# Epochs per episode: 1016 Episode Reward: 560.0 Episode number: 176
# Epochs per episode: 639 Episode Reward: 180.0 Episode number: 177
# Epochs per episode: 537 Episode Reward: 200.0 Episode number: 178
# Epochs per episode: 603 Episode Reward: 230.0 Episode number: 179
# Epochs per episode: 741 Episode Reward: 340.0 Episode number: 180
# Epochs per episode: 703 Episode Reward: 280.0 Episode number: 181
# Epochs per episode: 651 Episode Reward: 230.0 Episode number: 182
# Epochs per episode: 622 Episode Reward: 190.0 Episode number: 183
# Epochs per episode: 738 Episode Reward: 300.0 Episode number: 184
# Epochs per episode: 565 Episode Reward: 160.0 Episode number: 185
# Epochs per episode: 678 Episode Reward: 250.0 Episode number: 186
# Epochs per episode: 665 Episode Reward: 380.0 Episode number: 187
# Epochs per episode: 543 Episode Reward: 140.0 Episode number: 188
# Epochs per episode: 700 Episode Reward: 250.0 Episode number: 189
# Epochs per episode: 658 Episode Reward: 200.0 Episode number: 190
# Epochs per episode: 631 Episode Reward: 240.0 Episode number: 191
# Epochs per episode: 686 Episode Reward: 270.0 Episode number: 192
# Epochs per episode: 651 Episode Reward: 300.0 Episode number: 193
# Epochs per episode: 655 Episode Reward: 260.0 Episode number: 194
# Epochs per episode: 1006 Episode Reward: 1060.0 Episode number: 195
# Epochs per episode: 637 Episode Reward: 270.0 Episode number: 196
# Epochs per episode: 564 Episode Reward: 180.0 Episode number: 197
# Epochs per episode: 941 Episode Reward: 400.0 Episode number: 198
# Epochs per episode: 755 Episode Reward: 270.0 Episode number: 199
# Epochs per episode: 991 Episode Reward: 310.0 Episode number: 200
# Epochs per episode: 599 Episode Reward: 340.0 Episode number: 201
# Epochs per episode: 639 Episode Reward: 200.0 Episode number: 202
# Epochs per episode: 408 Episode Reward: 100.0 Episode number: 203
# Epochs per episode: 627 Episode Reward: 270.0 Episode number: 204
# Epochs per episode: 607 Episode Reward: 230.0 Episode number: 205
# Epochs per episode: 691 Episode Reward: 270.0 Episode number: 206
# Epochs per episode: 672 Episode Reward: 270.0 Episode number: 207
# Epochs per episode: 631 Episode Reward: 220.0 Episode number: 208
# Epochs per episode: 758 Episode Reward: 300.0 Episode number: 209
# Epochs per episode: 509 Episode Reward: 260.0 Episode number: 210
# Epochs per episode: 652 Episode Reward: 380.0 Episode number: 211
# Epochs per episode: 681 Episode Reward: 210.0 Episode number: 212
# Epochs per episode: 701 Episode Reward: 380.0 Episode number: 213
# Epochs per episode: 690 Episode Reward: 210.0 Episode number: 214
# Epochs per episode: 536 Episode Reward: 190.0 Episode number: 215
# Epochs per episode: 568 Episode Reward: 220.0 Episode number: 216
# Epochs per episode: 751 Episode Reward: 270.0 Episode number: 217
# Epochs per episode: 625 Episode Reward: 240.0 Episode number: 218
# Epochs per episode: 424 Episode Reward: 130.0 Episode number: 219
# Epochs per episode: 904 Episode Reward: 650.0 Episode number: 220
# Epochs per episode: 653 Episode Reward: 180.0 Episode number: 221
# Epochs per episode: 720 Episode Reward: 280.0 Episode number: 222
# Epochs per episode: 789 Episode Reward: 290.0 Episode number: 223
# Epochs per episode: 536 Episode Reward: 210.0 Episode number: 224
# Epochs per episode: 591 Episode Reward: 250.0 Episode number: 225
# Epochs per episode: 1015 Episode Reward: 740.0 Episode number: 226
# Epochs per episode: 654 Episode Reward: 270.0 Episode number: 227
# Epochs per episode: 920 Episode Reward: 850.0 Episode number: 228
# Epochs per episode: 647 Episode Reward: 280.0 Episode number: 229
# Epochs per episode: 485 Episode Reward: 200.0 Episode number: 230
# Epochs per episode: 638 Episode Reward: 350.0 Episode number: 231
# Epochs per episode: 539 Episode Reward: 190.0 Episode number: 232
# Epochs per episode: 900 Episode Reward: 640.0 Episode number: 233
# Epochs per episode: 555 Episode Reward: 180.0 Episode number: 234
# Epochs per episode: 806 Episode Reward: 270.0 Episode number: 235
# Epochs per episode: 678 Episode Reward: 390.0 Episode number: 236
# Epochs per episode: 561 Episode Reward: 290.0 Episode number: 237
# Epochs per episode: 536 Episode Reward: 220.0 Episode number: 238
# Epochs per episode: 631 Episode Reward: 290.0 Episode number: 239
# Epochs per episode: 755 Episode Reward: 370.0 Episode number: 240
# Epochs per episode: 618 Episode Reward: 320.0 Episode number: 241
# Epochs per episode: 557 Episode Reward: 220.0 Episode number: 242
# Epochs per episode: 675 Episode Reward: 240.0 Episode number: 243
# Epochs per episode: 611 Episode Reward: 260.0 Episode number: 244
# Epochs per episode: 509 Episode Reward: 280.0 Episode number: 245
# Epochs per episode: 497 Episode Reward: 210.0 Episode number: 246
# Epochs per episode: 606 Episode Reward: 150.0 Episode number: 247
# Epochs per episode: 784 Episode Reward: 320.0 Episode number: 248
# Epochs per episode: 591 Episode Reward: 300.0 Episode number: 249
# Epochs per episode: 669 Episode Reward: 240.0 Episode number: 250
# Epochs per episode: 803 Episode Reward: 400.0 Episode number: 251
# Epochs per episode: 683 Episode Reward: 280.0 Episode number: 252
# Epochs per episode: 557 Episode Reward: 250.0 Episode number: 253
# Epochs per episode: 707 Episode Reward: 260.0 Episode number: 254
# Epochs per episode: 991 Episode Reward: 590.0 Episode number: 255
# Epochs per episode: 484 Episode Reward: 180.0 Episode number: 256
# Epochs per episode: 968 Episode Reward: 730.0 Episode number: 257
# Epochs per episode: 613 Episode Reward: 230.0 Episode number: 258
# Epochs per episode: 678 Episode Reward: 220.0 Episode number: 259
# Epochs per episode: 722 Episode Reward: 340.0 Episode number: 260
# Epochs per episode: 608 Episode Reward: 340.0 Episode number: 261
# Epochs per episode: 676 Episode Reward: 270.0 Episode number: 262
# Epochs per episode: 520 Episode Reward: 180.0 Episode number: 263
# Epochs per episode: 684 Episode Reward: 360.0 Episode number: 264
# Epochs per episode: 566 Episode Reward: 140.0 Episode number: 265
# Epochs per episode: 640 Episode Reward: 270.0 Episode number: 266
# Epochs per episode: 782 Episode Reward: 160.0 Episode number: 267
# Epochs per episode: 546 Episode Reward: 290.0 Episode number: 268
# Epochs per episode: 1077 Episode Reward: 520.0 Episode number: 269
# Epochs per episode: 689 Episode Reward: 290.0 Episode number: 270
# Epochs per episode: 563 Episode Reward: 240.0 Episode number: 271
# Epochs per episode: 713 Episode Reward: 420.0 Episode number: 272
# Epochs per episode: 573 Episode Reward: 260.0 Episode number: 273
# Epochs per episode: 501 Episode Reward: 150.0 Episode number: 274
# Epochs per episode: 1073 Episode Reward: 680.0 Episode number: 275
# Epochs per episode: 760 Episode Reward: 410.0 Episode number: 276
# Epochs per episode: 632 Episode Reward: 270.0 Episode number: 277
# Epochs per episode: 615 Episode Reward: 220.0 Episode number: 278
# Epochs per episode: 535 Episode Reward: 220.0 Episode number: 279
# Epochs per episode: 543 Episode Reward: 290.0 Episode number: 280
# Epochs per episode: 682 Episode Reward: 350.0 Episode number: 281
# Epochs per episode: 414 Episode Reward: 70.0 Episode number: 282
# Epochs per episode: 425 Episode Reward: 130.0 Episode number: 283
# Epochs per episode: 605 Episode Reward: 320.0 Episode number: 284
# Epochs per episode: 549 Episode Reward: 220.0 Episode number: 285
# Epochs per episode: 573 Episode Reward: 290.0 Episode number: 286
# Epochs per episode: 545 Episode Reward: 210.0 Episode number: 287
# Epochs per episode: 756 Episode Reward: 320.0 Episode number: 288
# Epochs per episode: 823 Episode Reward: 950.0 Episode number: 289
# Epochs per episode: 517 Episode Reward: 200.0 Episode number: 290
# Epochs per episode: 819 Episode Reward: 460.0 Episode number: 291
# Epochs per episode: 580 Episode Reward: 230.0 Episode number: 292
# Epochs per episode: 846 Episode Reward: 700.0 Episode number: 293
# Epochs per episode: 661 Episode Reward: 250.0 Episode number: 294
# Epochs per episode: 1132 Episode Reward: 1240.0 Episode number: 295
# Epochs per episode: 930 Episode Reward: 470.0 Episode number: 296
# Epochs per episode: 539 Episode Reward: 260.0 Episode number: 297
# Epochs per episode: 562 Episode Reward: 240.0 Episode number: 298
# Epochs per episode: 721 Episode Reward: 280.0 Episode number: 299
# Epochs per episode: 615 Episode Reward: 260.0 Episode number: 300
# Epochs per episode: 655 Episode Reward: 240.0 Episode number: 301
# Epochs per episode: 666 Episode Reward: 400.0 Episode number: 302
# Epochs per episode: 667 Episode Reward: 320.0 Episode number: 303
# Epochs per episode: 775 Episode Reward: 410.0 Episode number: 304
# Epochs per episode: 626 Episode Reward: 300.0 Episode number: 305
# Epochs per episode: 642 Episode Reward: 290.0 Episode number: 306
# Epochs per episode: 449 Episode Reward: 140.0 Episode number: 307
# Epochs per episode: 676 Episode Reward: 310.0 Episode number: 308
# Epochs per episode: 585 Episode Reward: 360.0 Episode number: 309
# Epochs per episode: 881 Episode Reward: 470.0 Episode number: 310
# Epochs per episode: 683 Episode Reward: 240.0 Episode number: 311
# Epochs per episode: 540 Episode Reward: 280.0 Episode number: 312
# Epochs per episode: 747 Episode Reward: 340.0 Episode number: 313
# Epochs per episode: 628 Episode Reward: 330.0 Episode number: 314
# Epochs per episode: 640 Episode Reward: 190.0 Episode number: 315
# Epochs per episode: 653 Episode Reward: 200.0 Episode number: 316
# Epochs per episode: 700 Episode Reward: 240.0 Episode number: 317
# Epochs per episode: 1027 Episode Reward: 1260.0 Episode number: 318
# Epochs per episode: 646 Episode Reward: 370.0 Episode number: 319
# Epochs per episode: 767 Episode Reward: 410.0 Episode number: 320
# Epochs per episode: 685 Episode Reward: 360.0 Episode number: 321
# Epochs per episode: 564 Episode Reward: 130.0 Episode number: 322
# Epochs per episode: 726 Episode Reward: 350.0 Episode number: 323
# Epochs per episode: 771 Episode Reward: 500.0 Episode number: 324
# Epochs per episode: 929 Episode Reward: 640.0 Episode number: 325
# Epochs per episode: 548 Episode Reward: 360.0 Episode number: 326
# Epochs per episode: 1111 Episode Reward: 720.0 Episode number: 327
# Epochs per episode: 963 Episode Reward: 520.0 Episode number: 328
# Epochs per episode: 1069 Episode Reward: 1290.0 Episode number: 329
# Epochs per episode: 1341 Episode Reward: 930.0 Episode number: 330
# Epochs per episode: 573 Episode Reward: 210.0 Episode number: 331
# Epochs per episode: 781 Episode Reward: 500.0 Episode number: 332
# Epochs per episode: 458 Episode Reward: 220.0 Episode number: 333
# Epochs per episode: 603 Episode Reward: 270.0 Episode number: 334
# Epochs per episode: 558 Episode Reward: 220.0 Episode number: 335
# Epochs per episode: 819 Episode Reward: 500.0 Episode number: 336
# Epochs per episode: 1572 Episode Reward: 970.0 Episode number: 337
# Epochs per episode: 1057 Episode Reward: 530.0 Episode number: 338
# Epochs per episode: 575 Episode Reward: 310.0 Episode number: 339
# Epochs per episode: 782 Episode Reward: 320.0 Episode number: 340
# Epochs per episode: 548 Episode Reward: 240.0 Episode number: 341
# Epochs per episode: 778 Episode Reward: 370.0 Episode number: 342
# Epochs per episode: 890 Episode Reward: 830.0 Episode number: 343
# Epochs per episode: 664 Episode Reward: 260.0 Episode number: 344
# Epochs per episode: 626 Episode Reward: 420.0 Episode number: 345
# Epochs per episode: 818 Episode Reward: 690.0 Episode number: 346
# Epochs per episode: 554 Episode Reward: 280.0 Episode number: 347
# Epochs per episode: 655 Episode Reward: 240.0 Episode number: 348
# Epochs per episode: 936 Episode Reward: 1110.0 Episode number: 349
# Epochs per episode: 1102 Episode Reward: 2040.0 Episode number: 350
# Epochs per episode: 711 Episode Reward: 430.0 Episode number: 351
# Epochs per episode: 555 Episode Reward: 170.0 Episode number: 352
# Epochs per episode: 878 Episode Reward: 570.0 Episode number: 353
# Epochs per episode: 638 Episode Reward: 340.0 Episode number: 354
# Epochs per episode: 457 Episode Reward: 130.0 Episode number: 355
# Epochs per episode: 939 Episode Reward: 440.0 Episode number: 356
# Epochs per episode: 712 Episode Reward: 270.0 Episode number: 357
# Epochs per episode: 605 Episode Reward: 380.0 Episode number: 358
# Epochs per episode: 464 Episode Reward: 250.0 Episode number: 359
# Epochs per episode: 784 Episode Reward: 270.0 Episode number: 360
# Epochs per episode: 557 Episode Reward: 260.0 Episode number: 361
# Epochs per episode: 704 Episode Reward: 480.0 Episode number: 362
# Epochs per episode: 1165 Episode Reward: 1230.0 Episode number: 363
# Epochs per episode: 1012 Episode Reward: 830.0 Episode number: 364
# Epochs per episode: 676 Episode Reward: 280.0 Episode number: 365
# Epochs per episode: 777 Episode Reward: 630.0 Episode number: 366
# Epochs per episode: 959 Episode Reward: 1950.0 Episode number: 367
# Epochs per episode: 1078 Episode Reward: 720.0 Episode number: 368
# Epochs per episode: 607 Episode Reward: 470.0 Episode number: 369
# Epochs per episode: 667 Episode Reward: 270.0 Episode number: 370
# Epochs per episode: 531 Episode Reward: 120.0 Episode number: 371
# Epochs per episode: 1148 Episode Reward: 510.0 Episode number: 372
# Epochs per episode: 1096 Episode Reward: 650.0 Episode number: 373
# Epochs per episode: 647 Episode Reward: 350.0 Episode number: 374
# Epochs per episode: 607 Episode Reward: 330.0 Episode number: 375
# Epochs per episode: 1223 Episode Reward: 1060.0 Episode number: 376
# Epochs per episode: 690 Episode Reward: 390.0 Episode number: 377
# Epochs per episode: 849 Episode Reward: 550.0 Episode number: 378
# Epochs per episode: 1278 Episode Reward: 940.0 Episode number: 379
# Epochs per episode: 617 Episode Reward: 350.0 Episode number: 380
# Epochs per episode: 680 Episode Reward: 470.0 Episode number: 381
# Epochs per episode: 901 Episode Reward: 980.0 Episode number: 382
# Epochs per episode: 649 Episode Reward: 340.0 Episode number: 383
# Epochs per episode: 996 Episode Reward: 1340.0 Episode number: 384
# Epochs per episode: 507 Episode Reward: 230.0 Episode number: 385
# Epochs per episode: 673 Episode Reward: 370.0 Episode number: 386
# Epochs per episode: 738 Episode Reward: 330.0 Episode number: 387
# Epochs per episode: 739 Episode Reward: 310.0 Episode number: 388
# Epochs per episode: 539 Episode Reward: 190.0 Episode number: 389
# Epochs per episode: 852 Episode Reward: 520.0 Episode number: 390
# Epochs per episode: 729 Episode Reward: 430.0 Episode number: 391
# Epochs per episode: 530 Episode Reward: 300.0 Episode number: 392
# Epochs per episode: 556 Episode Reward: 200.0 Episode number: 393
# Epochs per episode: 1141 Episode Reward: 610.0 Episode number: 394
# Epochs per episode: 529 Episode Reward: 300.0 Episode number: 395
# Epochs per episode: 927 Episode Reward: 940.0 Episode number: 396
# Epochs per episode: 620 Episode Reward: 390.0 Episode number: 397
# Epochs per episode: 861 Episode Reward: 630.0 Episode number: 398
# Epochs per episode: 631 Episode Reward: 440.0 Episode number: 399
# Epochs per episode: 621 Episode Reward: 310.0 Episode number: 400
# Epochs per episode: 1076 Episode Reward: 790.0 Episode number: 401
# Epochs per episode: 660 Episode Reward: 390.0 Episode number: 402
# Epochs per episode: 746 Episode Reward: 450.0 Episode number: 403
# Epochs per episode: 639 Episode Reward: 440.0 Episode number: 404
# Epochs per episode: 849 Episode Reward: 1280.0 Episode number: 405
# Epochs per episode: 1288 Episode Reward: 1150.0 Episode number: 406
# Epochs per episode: 454 Episode Reward: 220.0 Episode number: 407
# Epochs per episode: 847 Episode Reward: 500.0 Episode number: 408
# Epochs per episode: 700 Episode Reward: 200.0 Episode number: 409
# Epochs per episode: 494 Episode Reward: 340.0 Episode number: 410
# Epochs per episode: 905 Episode Reward: 500.0 Episode number: 411
# Epochs per episode: 1079 Episode Reward: 810.0 Episode number: 412
# Epochs per episode: 460 Episode Reward: 250.0 Episode number: 413
# Epochs per episode: 606 Episode Reward: 360.0 Episode number: 414
# Epochs per episode: 702 Episode Reward: 400.0 Episode number: 415
# Epochs per episode: 698 Episode Reward: 400.0 Episode number: 416
# Epochs per episode: 1133 Episode Reward: 1160.0 Episode number: 417
# Epochs per episode: 918 Episode Reward: 1120.0 Episode number: 418
# Epochs per episode: 861 Episode Reward: 260.0 Episode number: 419
# Epochs per episode: 940 Episode Reward: 420.0 Episode number: 420
# Epochs per episode: 492 Episode Reward: 190.0 Episode number: 421
# Epochs per episode: 850 Episode Reward: 530.0 Episode number: 422
# Epochs per episode: 935 Episode Reward: 460.0 Episode number: 423
# Epochs per episode: 1122 Episode Reward: 810.0 Episode number: 424
# Epochs per episode: 603 Episode Reward: 290.0 Episode number: 425
# Epochs per episode: 803 Episode Reward: 350.0 Episode number: 426
# Epochs per episode: 813 Episode Reward: 610.0 Episode number: 427
# Epochs per episode: 658 Episode Reward: 290.0 Episode number: 428
# Epochs per episode: 950 Episode Reward: 710.0 Episode number: 429
# Epochs per episode: 712 Episode Reward: 350.0 Episode number: 430
# Epochs per episode: 538 Episode Reward: 300.0 Episode number: 431
# Epochs per episode: 759 Episode Reward: 500.0 Episode number: 432
# Epochs per episode: 618 Episode Reward: 390.0 Episode number: 433
# Epochs per episode: 816 Episode Reward: 730.0 Episode number: 434
# Epochs per episode: 820 Episode Reward: 750.0 Episode number: 435
# Epochs per episode: 923 Episode Reward: 460.0 Episode number: 436
# Epochs per episode: 809 Episode Reward: 1090.0 Episode number: 437
# Epochs per episode: 492 Episode Reward: 150.0 Episode number: 438
# Epochs per episode: 901 Episode Reward: 680.0 Episode number: 439
# Epochs per episode: 653 Episode Reward: 540.0 Episode number: 440
# Epochs per episode: 659 Episode Reward: 190.0 Episode number: 441
# Epochs per episode: 930 Episode Reward: 400.0 Episode number: 442
# Epochs per episode: 1388 Episode Reward: 1170.0 Episode number: 443
# Epochs per episode: 551 Episode Reward: 270.0 Episode number: 444
# Epochs per episode: 927 Episode Reward: 730.0 Episode number: 445
# Epochs per episode: 666 Episode Reward: 350.0 Episode number: 446
# Epochs per episode: 689 Episode Reward: 240.0 Episode number: 447
# Epochs per episode: 586 Episode Reward: 340.0 Episode number: 448
# Epochs per episode: 566 Episode Reward: 220.0 Episode number: 449
# Epochs per episode: 945 Episode Reward: 810.0 Episode number: 450
# Epochs per episode: 984 Episode Reward: 690.0 Episode number: 451
# Epochs per episode: 877 Episode Reward: 590.0 Episode number: 452
# Epochs per episode: 584 Episode Reward: 270.0 Episode number: 453
# Epochs per episode: 763 Episode Reward: 610.0 Episode number: 454
# Epochs per episode: 797 Episode Reward: 500.0 Episode number: 455
# Epochs per episode: 834 Episode Reward: 650.0 Episode number: 456
# Epochs per episode: 444 Episode Reward: 230.0 Episode number: 457
# Epochs per episode: 729 Episode Reward: 330.0 Episode number: 458
# Epochs per episode: 679 Episode Reward: 240.0 Episode number: 459
# Epochs per episode: 726 Episode Reward: 240.0 Episode number: 460
# Epochs per episode: 584 Episode Reward: 290.0 Episode number: 461
# Epochs per episode: 895 Episode Reward: 470.0 Episode number: 462
# Epochs per episode: 835 Episode Reward: 560.0 Episode number: 463
# Epochs per episode: 757 Episode Reward: 1000.0 Episode number: 464
# Epochs per episode: 940 Episode Reward: 810.0 Episode number: 465
# Epochs per episode: 659 Episode Reward: 320.0 Episode number: 466
# Epochs per episode: 526 Episode Reward: 280.0 Episode number: 467
# Epochs per episode: 682 Episode Reward: 390.0 Episode number: 468
# Epochs per episode: 550 Episode Reward: 260.0 Episode number: 469
# Epochs per episode: 674 Episode Reward: 450.0 Episode number: 470
# Epochs per episode: 974 Episode Reward: 660.0 Episode number: 471
# Epochs per episode: 749 Episode Reward: 400.0 Episode number: 472
# Epochs per episode: 896 Episode Reward: 1300.0 Episode number: 473
# Epochs per episode: 515 Episode Reward: 240.0 Episode number: 474
# Epochs per episode: 1146 Episode Reward: 1210.0 Episode number: 475
# Epochs per episode: 644 Episode Reward: 310.0 Episode number: 476
# Epochs per episode: 566 Episode Reward: 230.0 Episode number: 477
# Epochs per episode: 1474 Episode Reward: 2610.0 Episode number: 478
# Epochs per episode: 854 Episode Reward: 560.0 Episode number: 479
# Epochs per episode: 1032 Episode Reward: 750.0 Episode number: 480
# Epochs per episode: 732 Episode Reward: 470.0 Episode number: 481
# Epochs per episode: 590 Episode Reward: 400.0 Episode number: 482
# Epochs per episode: 865 Episode Reward: 550.0 Episode number: 483
# Epochs per episode: 549 Episode Reward: 400.0 Episode number: 484
# Epochs per episode: 1203 Episode Reward: 1180.0 Episode number: 485
# Epochs per episode: 735 Episode Reward: 540.0 Episode number: 486
# Epochs per episode: 893 Episode Reward: 590.0 Episode number: 487
# Epochs per episode: 957 Episode Reward: 640.0 Episode number: 488
# Epochs per episode: 667 Episode Reward: 540.0 Episode number: 489
# Epochs per episode: 827 Episode Reward: 1080.0 Episode number: 490
# Epochs per episode: 1042 Episode Reward: 970.0 Episode number: 491
# Epochs per episode: 617 Episode Reward: 220.0 Episode number: 492
# Epochs per episode: 630 Episode Reward: 310.0 Episode number: 493
# Epochs per episode: 1104 Episode Reward: 1010.0 Episode number: 494
# Epochs per episode: 887 Episode Reward: 430.0 Episode number: 495
# Epochs per episode: 462 Episode Reward: 370.0 Episode number: 496
# Epochs per episode: 566 Episode Reward: 320.0 Episode number: 497
# Epochs per episode: 1111 Episode Reward: 1210.0 Episode number: 498
# Epochs per episode: 1153 Episode Reward: 1310.0 Episode number: 499
# Epochs per episode: 427 Episode Reward: 160.0 Episode number: 500
# Epochs per episode: 878 Episode Reward: 710.0 Episode number: 501
# Epochs per episode: 787 Episode Reward: 420.0 Episode number: 502
# Epochs per episode: 598 Episode Reward: 440.0 Episode number: 503
# Epochs per episode: 1321 Episode Reward: 1190.0 Episode number: 504
# Epochs per episode: 703 Episode Reward: 500.0 Episode number: 505
# Epochs per episode: 834 Episode Reward: 690.0 Episode number: 506
# Epochs per episode: 966 Episode Reward: 620.0 Episode number: 507
# Epochs per episode: 679 Episode Reward: 530.0 Episode number: 508
# Epochs per episode: 768 Episode Reward: 570.0 Episode number: 509
# Epochs per episode: 1010 Episode Reward: 790.0 Episode number: 510
# Epochs per episode: 867 Episode Reward: 710.0 Episode number: 511
# Epochs per episode: 899 Episode Reward: 380.0 Episode number: 512
# Epochs per episode: 1362 Episode Reward: 810.0 Episode number: 513
# Epochs per episode: 1170 Episode Reward: 1560.0 Episode number: 514
# Epochs per episode: 768 Episode Reward: 550.0 Episode number: 515
# Epochs per episode: 1345 Episode Reward: 2260.0 Episode number: 516
# Epochs per episode: 887 Episode Reward: 1130.0 Episode number: 517
# Epochs per episode: 936 Episode Reward: 280.0 Episode number: 518
# Epochs per episode: 815 Episode Reward: 750.0 Episode number: 519
# Epochs per episode: 1271 Episode Reward: 2130.0 Episode number: 520
# Epochs per episode: 1089 Episode Reward: 1020.0 Episode number: 521
# Epochs per episode: 739 Episode Reward: 460.0 Episode number: 522
# Epochs per episode: 1256 Episode Reward: 1610.0 Episode number: 523
# Epochs per episode: 841 Episode Reward: 470.0 Episode number: 524
# Epochs per episode: 607 Episode Reward: 400.0 Episode number: 525
# Epochs per episode: 527 Episode Reward: 290.0 Episode number: 526
# Epochs per episode: 524 Episode Reward: 380.0 Episode number: 527
# Epochs per episode: 636 Episode Reward: 410.0 Episode number: 528
# Epochs per episode: 1008 Episode Reward: 750.0 Episode number: 529
# Epochs per episode: 861 Episode Reward: 940.0 Episode number: 530
# Epochs per episode: 666 Episode Reward: 520.0 Episode number: 531
# Epochs per episode: 775 Episode Reward: 480.0 Episode number: 532
# Epochs per episode: 778 Episode Reward: 410.0 Episode number: 533
# Epochs per episode: 1103 Episode Reward: 1050.0 Episode number: 534
# Epochs per episode: 592 Episode Reward: 330.0 Episode number: 535
# Epochs per episode: 726 Episode Reward: 540.0 Episode number: 536
# Epochs per episode: 1247 Episode Reward: 660.0 Episode number: 537
# Epochs per episode: 759 Episode Reward: 340.0 Episode number: 538
# Epochs per episode: 692 Episode Reward: 610.0 Episode number: 539
# Epochs per episode: 928 Episode Reward: 630.0 Episode number: 540
# Epochs per episode: 624 Episode Reward: 390.0 Episode number: 541
# Epochs per episode: 816 Episode Reward: 350.0 Episode number: 542
# Epochs per episode: 1036 Episode Reward: 750.0 Episode number: 543
# Epochs per episode: 1008 Episode Reward: 1130.0 Episode number: 544
# Epochs per episode: 1057 Episode Reward: 1230.0 Episode number: 545
# Epochs per episode: 585 Episode Reward: 360.0 Episode number: 546
# Epochs per episode: 528 Episode Reward: 400.0 Episode number: 547
# Epochs per episode: 765 Episode Reward: 660.0 Episode number: 548
# Epochs per episode: 961 Episode Reward: 570.0 Episode number: 549
# Epochs per episode: 649 Episode Reward: 360.0 Episode number: 550
# Epochs per episode: 750 Episode Reward: 350.0 Episode number: 551
# Epochs per episode: 547 Episode Reward: 390.0 Episode number: 552
# Epochs per episode: 709 Episode Reward: 560.0 Episode number: 553
# Epochs per episode: 840 Episode Reward: 600.0 Episode number: 554
# Epochs per episode: 649 Episode Reward: 270.0 Episode number: 555
# Epochs per episode: 519 Episode Reward: 290.0 Episode number: 556
# Epochs per episode: 616 Episode Reward: 570.0 Episode number: 557
# Epochs per episode: 573 Episode Reward: 310.0 Episode number: 558
# Epochs per episode: 867 Episode Reward: 780.0 Episode number: 559
# Epochs per episode: 871 Episode Reward: 890.0 Episode number: 560
# Epochs per episode: 1031 Episode Reward: 830.0 Episode number: 561
# Epochs per episode: 448 Episode Reward: 350.0 Episode number: 562
# Epochs per episode: 1128 Episode Reward: 1070.0 Episode number: 563
# Epochs per episode: 1252 Episode Reward: 2080.0 Episode number: 564
# Epochs per episode: 772 Episode Reward: 470.0 Episode number: 565
# Epochs per episode: 510 Episode Reward: 260.0 Episode number: 566
# Epochs per episode: 738 Episode Reward: 510.0 Episode number: 567
# Epochs per episode: 613 Episode Reward: 440.0 Episode number: 568
# Epochs per episode: 1057 Episode Reward: 730.0 Episode number: 569
# Epochs per episode: 812 Episode Reward: 660.0 Episode number: 570
# Epochs per episode: 859 Episode Reward: 260.0 Episode number: 571
# Epochs per episode: 688 Episode Reward: 420.0 Episode number: 572
# Epochs per episode: 827 Episode Reward: 1350.0 Episode number: 573
# Epochs per episode: 623 Episode Reward: 330.0 Episode number: 574
# Epochs per episode: 859 Episode Reward: 870.0 Episode number: 575
# Epochs per episode: 1224 Episode Reward: 770.0 Episode number: 576
# Epochs per episode: 805 Episode Reward: 540.0 Episode number: 577
# Epochs per episode: 696 Episode Reward: 640.0 Episode number: 578
# Epochs per episode: 959 Episode Reward: 980.0 Episode number: 579
# Epochs per episode: 1107 Episode Reward: 790.0 Episode number: 580
# Epochs per episode: 810 Episode Reward: 1220.0 Episode number: 581
# Epochs per episode: 886 Episode Reward: 520.0 Episode number: 582
# Epochs per episode: 1082 Episode Reward: 2020.0 Episode number: 583
# Epochs per episode: 666 Episode Reward: 470.0 Episode number: 584
# Epochs per episode: 931 Episode Reward: 1000.0 Episode number: 585
# Epochs per episode: 808 Episode Reward: 770.0 Episode number: 586
# Epochs per episode: 879 Episode Reward: 610.0 Episode number: 587
# Epochs per episode: 1049 Episode Reward: 510.0 Episode number: 588
# Epochs per episode: 1130 Episode Reward: 580.0 Episode number: 589
# Epochs per episode: 804 Episode Reward: 1110.0 Episode number: 590
# Epochs per episode: 807 Episode Reward: 500.0 Episode number: 591
# Epochs per episode: 1623 Episode Reward: 2120.0 Episode number: 592
# Epochs per episode: 695 Episode Reward: 390.0 Episode number: 593
# Epochs per episode: 860 Episode Reward: 440.0 Episode number: 594
# Epochs per episode: 620 Episode Reward: 430.0 Episode number: 595
# Epochs per episode: 400 Episode Reward: 260.0 Episode number: 596
# Epochs per episode: 1077 Episode Reward: 580.0 Episode number: 597
# Epochs per episode: 785 Episode Reward: 260.0 Episode number: 598
# Epochs per episode: 712 Episode Reward: 290.0 Episode number: 599
# Epochs per episode: 814 Episode Reward: 330.0 Episode number: 600
# Epochs per episode: 513 Episode Reward: 370.0 Episode number: 601
# Epochs per episode: 753 Episode Reward: 990.0 Episode number: 602
# Epochs per episode: 1306 Episode Reward: 2090.0 Episode number: 603
# Epochs per episode: 925 Episode Reward: 1200.0 Episode number: 604
# Epochs per episode: 1113 Episode Reward: 2280.0 Episode number: 605
# Epochs per episode: 824 Episode Reward: 650.0 Episode number: 606
# Epochs per episode: 1125 Episode Reward: 610.0 Episode number: 607
# Epochs per episode: 973 Episode Reward: 740.0 Episode number: 608
# Epochs per episode: 982 Episode Reward: 750.0 Episode number: 609
# Epochs per episode: 613 Episode Reward: 320.0 Episode number: 610
# Epochs per episode: 887 Episode Reward: 680.0 Episode number: 611
# Epochs per episode: 928 Episode Reward: 1840.0 Episode number: 612
# Epochs per episode: 747 Episode Reward: 570.0 Episode number: 613
# Epochs per episode: 499 Episode Reward: 140.0 Episode number: 614
# Epochs per episode: 1074 Episode Reward: 2420.0 Episode number: 615
# Epochs per episode: 876 Episode Reward: 500.0 Episode number: 616
# Epochs per episode: 406 Episode Reward: 120.0 Episode number: 617
# Epochs per episode: 1020 Episode Reward: 710.0 Episode number: 618
# Epochs per episode: 905 Episode Reward: 530.0 Episode number: 619
# Epochs per episode: 937 Episode Reward: 1090.0 Episode number: 620
# Epochs per episode: 646 Episode Reward: 430.0 Episode number: 621
# Epochs per episode: 958 Episode Reward: 740.0 Episode number: 622
# Epochs per episode: 896 Episode Reward: 530.0 Episode number: 623
# Epochs per episode: 1062 Episode Reward: 1010.0 Episode number: 624
# Epochs per episode: 455 Episode Reward: 230.0 Episode number: 625
# Epochs per episode: 947 Episode Reward: 660.0 Episode number: 626
# Epochs per episode: 894 Episode Reward: 760.0 Episode number: 627
# Epochs per episode: 747 Episode Reward: 560.0 Episode number: 628
# Epochs per episode: 716 Episode Reward: 600.0 Episode number: 629
# Epochs per episode: 575 Episode Reward: 430.0 Episode number: 630
# Epochs per episode: 852 Episode Reward: 570.0 Episode number: 631
# Epochs per episode: 481 Episode Reward: 440.0 Episode number: 632
# Epochs per episode: 645 Episode Reward: 500.0 Episode number: 633
# Epochs per episode: 690 Episode Reward: 320.0 Episode number: 634
# Epochs per episode: 647 Episode Reward: 490.0 Episode number: 635
# Epochs per episode: 757 Episode Reward: 390.0 Episode number: 636
# Epochs per episode: 640 Episode Reward: 400.0 Episode number: 637
# Epochs per episode: 761 Episode Reward: 420.0 Episode number: 638
# Epochs per episode: 566 Episode Reward: 460.0 Episode number: 639
# Epochs per episode: 649 Episode Reward: 350.0 Episode number: 640
# Epochs per episode: 971 Episode Reward: 800.0 Episode number: 641
# Epochs per episode: 716 Episode Reward: 1050.0 Episode number: 642
# Epochs per episode: 579 Episode Reward: 350.0 Episode number: 643
# Epochs per episode: 501 Episode Reward: 180.0 Episode number: 644
# Epochs per episode: 914 Episode Reward: 780.0 Episode number: 645
# Epochs per episode: 565 Episode Reward: 390.0 Episode number: 646
# Epochs per episode: 787 Episode Reward: 1030.0 Episode number: 647
# Epochs per episode: 555 Episode Reward: 340.0 Episode number: 648
# Epochs per episode: 622 Episode Reward: 450.0 Episode number: 649
# Epochs per episode: 868 Episode Reward: 450.0 Episode number: 650
# Epochs per episode: 886 Episode Reward: 600.0 Episode number: 651
# Epochs per episode: 996 Episode Reward: 450.0 Episode number: 652
# Epochs per episode: 613 Episode Reward: 380.0 Episode number: 653
# Epochs per episode: 712 Episode Reward: 660.0 Episode number: 654
# Epochs per episode: 869 Episode Reward: 560.0 Episode number: 655
# Epochs per episode: 768 Episode Reward: 260.0 Episode number: 656
# Epochs per episode: 601 Episode Reward: 260.0 Episode number: 657
# Epochs per episode: 1220 Episode Reward: 500.0 Episode number: 658
# Epochs per episode: 641 Episode Reward: 310.0 Episode number: 659
# Epochs per episode: 516 Episode Reward: 160.0 Episode number: 660
# Epochs per episode: 1102 Episode Reward: 720.0 Episode number: 661
# Epochs per episode: 1196 Episode Reward: 670.0 Episode number: 662
# Epochs per episode: 593 Episode Reward: 420.0 Episode number: 663
# Epochs per episode: 589 Episode Reward: 290.0 Episode number: 664
# Epochs per episode: 1269 Episode Reward: 1000.0 Episode number: 665
# Epochs per episode: 520 Episode Reward: 160.0 Episode number: 666
# Epochs per episode: 697 Episode Reward: 370.0 Episode number: 667
# Epochs per episode: 583 Episode Reward: 280.0 Episode number: 668
# Epochs per episode: 772 Episode Reward: 240.0 Episode number: 669
# Epochs per episode: 630 Episode Reward: 250.0 Episode number: 670
# Epochs per episode: 1236 Episode Reward: 790.0 Episode number: 671
# Epochs per episode: 869 Episode Reward: 450.0 Episode number: 672
# Epochs per episode: 614 Episode Reward: 260.0 Episode number: 673
# Epochs per episode: 471 Episode Reward: 190.0 Episode number: 674
# Epochs per episode: 644 Episode Reward: 180.0 Episode number: 675
# Epochs per episode: 754 Episode Reward: 300.0 Episode number: 676
# Epochs per episode: 692 Episode Reward: 250.0 Episode number: 677
# Epochs per episode: 791 Episode Reward: 730.0 Episode number: 678
# Epochs per episode: 962 Episode Reward: 940.0 Episode number: 679
# Epochs per episode: 669 Episode Reward: 550.0 Episode number: 680
# Epochs per episode: 715 Episode Reward: 220.0 Episode number: 681
# Epochs per episode: 584 Episode Reward: 260.0 Episode number: 682
# Epochs per episode: 762 Episode Reward: 290.0 Episode number: 683
# Epochs per episode: 926 Episode Reward: 500.0 Episode number: 684
# Epochs per episode: 981 Episode Reward: 900.0 Episode number: 685
# Epochs per episode: 596 Episode Reward: 370.0 Episode number: 686
# Epochs per episode: 725 Episode Reward: 440.0 Episode number: 687
# Epochs per episode: 954 Episode Reward: 520.0 Episode number: 688
# Epochs per episode: 759 Episode Reward: 1050.0 Episode number: 689
# Epochs per episode: 913 Episode Reward: 920.0 Episode number: 690
# Epochs per episode: 1192 Episode Reward: 680.0 Episode number: 691
# Epochs per episode: 640 Episode Reward: 350.0 Episode number: 692
# Epochs per episode: 737 Episode Reward: 630.0 Episode number: 693
# Epochs per episode: 629 Episode Reward: 390.0 Episode number: 694
# Epochs per episode: 947 Episode Reward: 660.0 Episode number: 695
# Epochs per episode: 688 Episode Reward: 620.0 Episode number: 696
# Epochs per episode: 503 Episode Reward: 330.0 Episode number: 697
# Epochs per episode: 967 Episode Reward: 1840.0 Episode number: 698
# Epochs per episode: 631 Episode Reward: 260.0 Episode number: 699
# Epochs per episode: 586 Episode Reward: 250.0 Episode number: 700
# Epochs per episode: 738 Episode Reward: 650.0 Episode number: 701
# Epochs per episode: 797 Episode Reward: 630.0 Episode number: 702
# Epochs per episode: 823 Episode Reward: 490.0 Episode number: 703
# Epochs per episode: 1009 Episode Reward: 700.0 Episode number: 704
# Epochs per episode: 732 Episode Reward: 510.0 Episode number: 705
# Epochs per episode: 976 Episode Reward: 1640.0 Episode number: 706
# Epochs per episode: 812 Episode Reward: 550.0 Episode number: 707
# Epochs per episode: 839 Episode Reward: 490.0 Episode number: 708
# Epochs per episode: 760 Episode Reward: 420.0 Episode number: 709
# Epochs per episode: 1021 Episode Reward: 440.0 Episode number: 710
# Epochs per episode: 830 Episode Reward: 420.0 Episode number: 711
# Epochs per episode: 880 Episode Reward: 360.0 Episode number: 712
# Epochs per episode: 951 Episode Reward: 1740.0 Episode number: 713
# Epochs per episode: 879 Episode Reward: 320.0 Episode number: 714
# Epochs per episode: 830 Episode Reward: 440.0 Episode number: 715
# Epochs per episode: 939 Episode Reward: 490.0 Episode number: 716
# Epochs per episode: 921 Episode Reward: 240.0 Episode number: 717
# Epochs per episode: 922 Episode Reward: 850.0 Episode number: 718
# Epochs per episode: 1108 Episode Reward: 1080.0 Episode number: 719
# Epochs per episode: 872 Episode Reward: 610.0 Episode number: 720
# Epochs per episode: 980 Episode Reward: 590.0 Episode number: 721
# Epochs per episode: 846 Episode Reward: 490.0 Episode number: 722
# Epochs per episode: 900 Episode Reward: 450.0 Episode number: 723
# Epochs per episode: 555 Episode Reward: 150.0 Episode number: 724
# Epochs per episode: 841 Episode Reward: 1010.0 Episode number: 725
# Epochs per episode: 945 Episode Reward: 850.0 Episode number: 726
# Epochs per episode: 925 Episode Reward: 440.0 Episode number: 727
# Epochs per episode: 854 Episode Reward: 1660.0 Episode number: 728
# Epochs per episode: 893 Episode Reward: 330.0 Episode number: 729
# Epochs per episode: 884 Episode Reward: 660.0 Episode number: 730
# Epochs per episode: 893 Episode Reward: 800.0 Episode number: 731
# Epochs per episode: 592 Episode Reward: 390.0 Episode number: 732
# Epochs per episode: 767 Episode Reward: 250.0 Episode number: 733
# Epochs per episode: 978 Episode Reward: 910.0 Episode number: 734
# Epochs per episode: 568 Episode Reward: 260.0 Episode number: 735
# Epochs per episode: 899 Episode Reward: 600.0 Episode number: 736
# Epochs per episode: 825 Episode Reward: 640.0 Episode number: 737
# Epochs per episode: 1113 Episode Reward: 570.0 Episode number: 738
# Epochs per episode: 636 Episode Reward: 240.0 Episode number: 739
# Epochs per episode: 878 Episode Reward: 1060.0 Episode number: 740
# Epochs per episode: 765 Episode Reward: 540.0 Episode number: 741
# Epochs per episode: 654 Episode Reward: 380.0 Episode number: 742
# Epochs per episode: 913 Episode Reward: 540.0 Episode number: 743
# Epochs per episode: 925 Episode Reward: 350.0 Episode number: 744
# Epochs per episode: 680 Episode Reward: 560.0 Episode number: 745
# Epochs per episode: 1050 Episode Reward: 660.0 Episode number: 746
# Epochs per episode: 673 Episode Reward: 230.0 Episode number: 747
# Epochs per episode: 578 Episode Reward: 230.0 Episode number: 748
# Epochs per episode: 970 Episode Reward: 450.0 Episode number: 749
# Epochs per episode: 981 Episode Reward: 450.0 Episode number: 750
# Epochs per episode: 1422 Episode Reward: 250.0 Episode number: 751
# Epochs per episode: 1396 Episode Reward: 410.0 Episode number: 752
# Epochs per episode: 673 Episode Reward: 250.0 Episode number: 753
# Epochs per episode: 680 Episode Reward: 180.0 Episode number: 754
# Epochs per episode: 915 Episode Reward: 570.0 Episode number: 755
# Epochs per episode: 770 Episode Reward: 400.0 Episode number: 756
# Epochs per episode: 834 Episode Reward: 420.0 Episode number: 757
# Epochs per episode: 616 Episode Reward: 280.0 Episode number: 758
# Epochs per episode: 1145 Episode Reward: 1150.0 Episode number: 759
# Epochs per episode: 774 Episode Reward: 260.0 Episode number: 760
# Epochs per episode: 654 Episode Reward: 450.0 Episode number: 761
# Epochs per episode: 692 Episode Reward: 380.0 Episode number: 762
# Epochs per episode: 881 Episode Reward: 490.0 Episode number: 763
# Epochs per episode: 877 Episode Reward: 580.0 Episode number: 764
# Epochs per episode: 643 Episode Reward: 300.0 Episode number: 765
# Epochs per episode: 946 Episode Reward: 560.0 Episode number: 766
# Epochs per episode: 533 Episode Reward: 140.0 Episode number: 767
# Epochs per episode: 897 Episode Reward: 230.0 Episode number: 768
# Epochs per episode: 709 Episode Reward: 120.0 Episode number: 769
# Epochs per episode: 1202 Episode Reward: 1290.0 Episode number: 770
# Epochs per episode: 962 Episode Reward: 450.0 Episode number: 771
# Epochs per episode: 1152 Episode Reward: 180.0 Episode number: 772
# Epochs per episode: 526 Episode Reward: 190.0 Episode number: 773
# Epochs per episode: 695 Episode Reward: 110.0 Episode number: 774
# Epochs per episode: 892 Episode Reward: 450.0 Episode number: 775
# Epochs per episode: 726 Episode Reward: 180.0 Episode number: 776
# Epochs per episode: 745 Episode Reward: 400.0 Episode number: 777
# Epochs per episode: 700 Episode Reward: 280.0 Episode number: 778
# Epochs per episode: 870 Episode Reward: 240.0 Episode number: 779
# Epochs per episode: 670 Episode Reward: 300.0 Episode number: 780
# Epochs per episode: 843 Episode Reward: 180.0 Episode number: 781
# Epochs per episode: 806 Episode Reward: 180.0 Episode number: 782
# Epochs per episode: 822 Episode Reward: 380.0 Episode number: 783
# Epochs per episode: 1275 Episode Reward: 1270.0 Episode number: 784
# Epochs per episode: 599 Episode Reward: 340.0 Episode number: 785
# Epochs per episode: 1340 Episode Reward: 410.0 Episode number: 786
# Epochs per episode: 744 Episode Reward: 350.0 Episode number: 787
# Epochs per episode: 656 Episode Reward: 450.0 Episode number: 788
# Epochs per episode: 524 Episode Reward: 310.0 Episode number: 789
# Epochs per episode: 729 Episode Reward: 250.0 Episode number: 790
# Epochs per episode: 902 Episode Reward: 450.0 Episode number: 791
# Epochs per episode: 844 Episode Reward: 370.0 Episode number: 792
# Epochs per episode: 605 Episode Reward: 430.0 Episode number: 793
# Epochs per episode: 918 Episode Reward: 410.0 Episode number: 794
# Epochs per episode: 967 Episode Reward: 1010.0 Episode number: 795
# Epochs per episode: 775 Episode Reward: 310.0 Episode number: 796
# Epochs per episode: 752 Episode Reward: 580.0 Episode number: 797
# Epochs per episode: 799 Episode Reward: 330.0 Episode number: 798
# Epochs per episode: 751 Episode Reward: 430.0 Episode number: 799
# Epochs per episode: 932 Episode Reward: 290.0 Episode number: 800

# %% [markdown]
# Let's plot our reward distribution across the incremental episodes. Remember to interrupt the training process first.

# %%
plt.plot(history)
plt.show()

# %% [markdown]
# ## Evaluation
#
# Finally, let's visualize our agent's performance, and play a game within the gym environment itself.

# %%
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory

#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (46.0.0)

# %%
#To Evaluate model on OpenAI gym, we will record a video via Ipython display



from gym import logger as gymlogger
from gym.wrappers import Monitor
#gymlogger.set_level(795) #error only

import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay


from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# xdpyinfo was not found, X start can not be checked! Please install xdpyinfo!
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1025'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1400x900x24', ':1025'] oserror=None return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
#Evaluate model on openAi GYM
env = wrap_env(gym.make('MsPacman-v0'))
observation = env.reset()
new_observation = observation

prev_input = None
done = False

with tf.compat.v1.Session() as sess:
    init.run()
    while True:
      if True: 
    
        #set input to network to be difference image
    

        obs = preprocess_observation(observation)

        # feed the game screen and get the Q values for each action
        actions = mainQ_outputs.eval(feed_dict={X:[obs], in_training_mode:False})

        # get the action
        action = np.argmax(actions, axis=-1)
        actions_counter[str(action)] += 1 

        # select the action using epsilon greedy policy
        action = epsilon_greedy(action, global_step)
        env.render()
        observation = new_observation        
        # now perform the action and move to the next state, next_obs, receive reward
        new_observation, reward, done, _ = env.step(action)

        if done: 
          #observation = env.reset()
          break
      
    env.close()
    show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
